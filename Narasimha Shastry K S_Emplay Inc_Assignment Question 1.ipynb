# %% [markdown]
# # QUESTION - 1

# %% [markdown]
# ###### Note: Solution at the end of the file

# %% [markdown]
# ### DATA PREPROCESSING

# %%
#impoting required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#reading the csv file 'emplayquestwo.csv'
df = pd.read_csv('eqonecompone.csv')

# %%
#printing the first 5 rows of the dataset
df.head()
# Out:
#         Conversion Funnel Step   City  Number of Users on Step (MAY)  \
# 0          Landed on Main Page  Delhi                            100
# 1                  Started QnA  Delhi                             70
# 2  Viewed and Selected Package  Delhi                             43
# 3     Landed on Scheduler Page  Delhi                             25
# 4       Landed on payment Page  Delhi                             15
#
#   Step Level Conversion (MAY)  Number of Users on Step (JUNE)  \
# 0                     100.00%                             150
# 1                      70.00%                             105
# 2                      43.00%                              48
# 3                      25.00%                              28
# 4                      15.00%                              17
#
#   Step Level Conversion (JUNE)
# 0                      100.00%
# 1                       70.00%
# 2                       32.00%
# 3                       18.70%
# ...

# %%
#getting the dimensions of the dataset df i.e. rows and columns of the dataset 
print(df.shape)
# Out:
# (24, 6)

# %%
#printing the unique values for 'Conversion Funnel Step' and 'City' columns
print(df['Conversion Funnel Step'].unique())
print(df['City'].unique())
# Out:
# ['Landed on Main Page' 'Started QnA' 'Viewed and Selected Package'
#  'Landed on Scheduler Page' 'Landed on payment Page' 'Booking Success']
# ['Delhi' 'Bangalore' 'Mumbai' 'Hyderabad']

# %%
#calculating statistical data of the numerical values of the DataFrame
df.describe()
# Out:
#        Number of Users on Step (MAY)  Number of Users on Step (JUNE)
# count                      24.000000                       24.000000
# mean                       40.291667                       40.875000
# std                        32.201106                       39.537888
# min                         9.000000                        3.000000
# 25%                        13.500000                       10.250000
# 50%                        27.500000                       28.500000
# 75%                        66.250000                       60.250000
# max                       110.000000                      150.000000

# %%
#checking for null values. No null values found in the dataset.
df.isnull().sum()
# Out:
# Conversion Funnel Step            0
# City                              0
# Number of Users on Step (MAY)     0
# Step Level Conversion (MAY)       0
# Number of Users on Step (JUNE)    0
# Step Level Conversion (JUNE)      0
# dtype: int64

# %%
#getting a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Conversion Funnel Step          24 non-null     object
#  1   City                            24 non-null     object
#  2   Number of Users on Step (MAY)   24 non-null     int64
#  3   Step Level Conversion (MAY)     24 non-null     object
#  4   Number of Users on Step (JUNE)  24 non-null     int64
#  5   Step Level Conversion (JUNE)    24 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.2+ KB

# %%
#getting the correlation of the numerical values
df.corr()
# Out:
#                                 Number of Users on Step (MAY)  \
# Number of Users on Step (MAY)                        1.000000
# Number of Users on Step (JUNE)                       0.942803
#
#                                 Number of Users on Step (JUNE)
# Number of Users on Step (MAY)                         0.942803
# Number of Users on Step (JUNE)                        1.000000

# %%
#converting the % object value of the column 'Step Level Conversion (MAY)' to integer value
df['Step Level Conversion (MAY)']=df['Step Level Conversion (MAY)'].str.rstrip('%').astype(float).astype(int)

# %%
#converting the % object value of the column 'Step Level Conversion (JUNE)' to integer value
df['Step Level Conversion (JUNE)']=df['Step Level Conversion (JUNE)'].str.rstrip('%').astype(float).astype(int)

# %%
df.head()
# Out:
#         Conversion Funnel Step   City  Number of Users on Step (MAY)  \
# 0          Landed on Main Page  Delhi                            100
# 1                  Started QnA  Delhi                             70
# 2  Viewed and Selected Package  Delhi                             43
# 3     Landed on Scheduler Page  Delhi                             25
# 4       Landed on payment Page  Delhi                             15
#
#    Step Level Conversion (MAY)  Number of Users on Step (JUNE)  \
# 0                          100                             150
# 1                           70                             105
# 2                           43                              48
# 3                           25                              28
# 4                           15                              17
#
#    Step Level Conversion (JUNE)
# 0                           100
# 1                            70
# 2                            32
# 3                            18
# ...

# %%
#converting the columns of the dataset to a list of values
no_of_user_onstep_may_list = df['Number of Users on Step (MAY)'].tolist()
no_of_user_onstep_june_list = df['Number of Users on Step (JUNE)'].tolist()
no_of_user_steplevel_may_list = df['Step Level Conversion (MAY)'].tolist()
no_of_user_steplevel_june_list = df['Step Level Conversion (JUNE)'].tolist()
Conversion_Funnel_Step=df['Conversion Funnel Step'].unique().tolist()

# %%
a=df.City.value_counts().Delhi
a
# Out:
# 6

# %%
#creating dataframes of the particular cities
df_delhi=df.loc[df['City'] == 'Delhi']
df_Bangalore=df.loc[df['City'] == 'Bangalore']
df_Mumbai=df.loc[df['City'] == 'Mumbai']
df_Hyderabad=df.loc[df['City'] == 'Hyderabad']

# %%
###Plot_delhi_Conversion_Funnel_Step=df_delhi['Conversion Funnel Step']
###Plot_delhi_no_of_users_may=df_delhi['Number of Users on Step (MAY)']
###Plot_delhi_no_of_users_june=df_delhi['Number of Users on Step (JUNE)']
###Plot_delhi_Step_Level_Conversion_may=df_delhi['Step Level Conversion (MAY)']
###Plot_delhi_Step_Level_Conversion_june=df_delhi['Step Level Conversion (JUNE)']

# %%
#creating a grouped bar plot for Delhi for Number of users v/s Conversion Funnel Step for May and June
df_delhi.plot(x='Conversion Funnel Step',y=['Number of Users on Step (MAY)', 'Number of Users on Step (JUNE)'],kind="bar",figsize=(12,8),rot=25)
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Number_of_users")
plt.title("Number_of_users v/s Conversion_Funnel_Step Delhi")
plt.show()

# %%
#creating a grouped line plot for Delhi for Step Level Conversion v/s Conversion Funnel Step for May and June
df_delhi.plot(x='Conversion Funnel Step',y=['Step Level Conversion (MAY)', 'Step Level Conversion (JUNE)'],kind="line",figsize=(12,8),rot=25,grid=True,marker='o')
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Step Level Conversion(%)")
plt.title("Step_Level_Conversion v/s Conversion_Funnel_Step Delhi")
plt.show()

# %%
#creating a grouped bar plot for Bangalore for Number of users v/s Conversion Funnel Step for May and June
df_Bangalore.plot(x='Conversion Funnel Step',y=['Number of Users on Step (MAY)', 'Number of Users on Step (JUNE)'],kind="bar",figsize=(12,8),rot=25)
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Number_of_users")
plt.title("Number_of_users v/s Conversion_Funnel_Step Bangalore")
plt.show()

# %%
#creating a grouped line plot for Bangalore for Step Level Conversion v/s Conversion Funnel Step for May and June
df_Bangalore.plot(x='Conversion Funnel Step',y=['Step Level Conversion (MAY)', 'Step Level Conversion (JUNE)'],kind="line",figsize=(12,8),rot=25,grid=True,marker='o')
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Step Level Conversion(%)")
plt.title("Step_Level_Conversion v/s Conversion_Funnel_Step Bangalore")
plt.show()

# %%
#creating a grouped bar plot for Mumbai for Number of users v/s Conversion Funnel Step for May and June
df_Mumbai.plot(x='Conversion Funnel Step',y=['Number of Users on Step (MAY)', 'Number of Users on Step (JUNE)'],kind="bar",figsize=(12,8),rot=25)
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Number_of_users")
plt.title("Number_of_users v/s Conversion_Funnel_Step Mumbai")
plt.show()

# %%
#creating a grouped line plot for Mumbai for Step Level Conversion v/s Conversion Funnel Step for May and June
df_Mumbai.plot(x='Conversion Funnel Step',y=['Step Level Conversion (MAY)', 'Step Level Conversion (JUNE)'],kind="line",figsize=(12,8),rot=25,grid=True,marker='o')
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Step Level Conversion(%)")
plt.title("Step_Level_Conversion v/s Conversion_Funnel_Step Mumbai")
plt.show()

# %%
#creating a grouped bar plot for Hyderabad for Number of users v/s Conversion Funnel Step for May and June
df_Hyderabad.plot(x='Conversion Funnel Step',y=['Number of Users on Step (MAY)', 'Number of Users on Step (JUNE)'],kind="bar",figsize=(12,8),rot=25)
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Number_of_users")
plt.title("Number_of_users v/s Conversion_Funnel_Step Hyderabad")
plt.show()

# %%
#creating a grouped line plot for Hyderabad for Step Level Conversion v/s Conversion Funnel Step for May and June
df_Hyderabad.plot(x='Conversion Funnel Step',y=['Step Level Conversion (MAY)', 'Step Level Conversion (JUNE)'],kind="line",figsize=(12,8),rot=25,grid=True,marker='o')
plt.xlabel("Conversion_Funnel_Step")
plt.ylabel("Step_Level_Conversion(%)")
plt.title("Step_Level_Conversion v/s Conversion_Funnel_Step Hyderabad")
plt.show()

# %% [markdown]
# # SOLUTION FOR QUESTION - 1(a) ##################

# %% [markdown]
# ##### QUESTION 1(a) - In the month of May, overall conversion in Mumbai is low (8.2%) compared to the rest of the cities (around 12% in each). On observation we can notice that the cause of the drop is in step “Viewed and Selected Package” which has around 40% conversion in other cities while it is 27% in Mumbai (given 70% users start QnA in all cities). It looks like users are not adding packages to their cart. What could be the possible cause?

# %% [markdown]
# Low Conversion in Mumbai –
# The reason for low overall conversion in Mumbai (8.2%), can be attributed to huge drop in “Viewed and Selected Package” conversion.
# In Mumbai, 110 people land on the main age which is almost 10% more than Delhi and 13.6% more than Bangalore and 31.8% more than Hyderabad.
# 70% started QnA in Mumbai and this dropped to 27.3% in “Viewed and Selected Package”, there is a 43% drop. The possible reasons might be –
#
# 1. Pricing of service might be an issue, since cities are in different states with different cost of living. We have not been      provided sufficient data to conclude that  prices are differing.
# 2. Availability of services offered, might differ city to city. Which was observed when in the app.
# 3. Income disparity among the target population, Mumbai might have a more of lower middle class and middle class population        which might not be able to afford the cost of services provided
# 4. Partners – The customer satisfaction is also dependent on skill and professional conduct of the partner arriving at the home.    If the most highly skilled partners are unavailable then this will affect the booking success
# 5. Abundant availability of local brick and mortar solons and familiar hair specialist.

# %% [markdown]
# # SOLUTION FOR QUESTION - 1(b)

# %% [markdown]
# ##### QUESTION 1(a) - Conversion has dropped significantly in June across all cities. List out the steps where considerable drop has happened in each city compared to May. What could be the reasons for each of these drops?

# %% [markdown]
# Dropped Conversion in June –
# We see some major drop in following cities for conversion funnel step for June compared to May –
# 1. In Delhi, Viewed and Selected Package had a drop of 11%. Possible reason - The customer did not find  suitable Packages for      his/her range .
# 2. In Delhi, Landed on Scheduler Page had a drop of 6.3%. Possible Reason - The customer did not find suitable time slot as per    his/her requirement.
# 3. In Delhi, Booking success had a drop of 7.3%. Possible Reason - The booking order was cancelled  by the partner.
# 4. In Bangalore, Landed on Scheduler Page has a drop of 9.2%. Possible Reason - The customer did not find     suitable time slot    as per his/her requirement.
# 5. In Bangalore, Booking success Page has a drop of 7.8%. Possible Reason - The booking order was cancelled by the partner.
# 6. In Hyderabad, Landed on payment Page has a drop of 6%. Possible Reason - Technical glitch, unsuccessful payment.
# 7. In Hyderabad, Booking success Page has a drop of 8.2%.  Possible Reason - The booking order was cancelled by the partner.
